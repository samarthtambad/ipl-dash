# %%
import pandas as pd

# %%
matches_df = pd.read_csv('/Users/samarth/Workspace/ipl-dash/src/assets/data/csv_files/processed/matches_modified.csv')

# %%
matches_df.head()
# Out:
#    match       date                       team_1                       team_2  \
# 0      1  18-Apr-08  Royal Challengers Bangalore        Kolkata Knight Riders
# 1      2  19-Apr-08              Kings XI Punjab          Chennai Super Kings
# 2      3  19-Apr-08             Delhi Daredevils             Rajasthan Royals
# 3      4  20-Apr-08               Mumbai Indians  Royal Challengers Bangalore
# 4      5  20-Apr-08        Kolkata Knight Riders              Deccan Chargers
#
#    season                                       venue  \
# 0       1                       M Chinnaswamy Stadium
# 1       1  Punjab Cricket Association Stadium, Mohali
# 2       1                            Feroz Shah Kotla
# 3       1                            Wankhede Stadium
# 4       1                                Eden Gardens
#
#                    toss_winner toss_decision  is_superover  is_result  \
# 0  Royal Challengers Bangalore         field             0          1
# ...
